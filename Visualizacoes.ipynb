# %%
import seaborn as sns
import glob as gb
import os
import pickle
import sys
from Utils import utils

# %%
# %matplotlib inline

# %% [markdown]
# # Getting most recent file and read

# %%
Extract = utils()      
dataframe = Extract.GetLastPickle()

# %%
dataframe.head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.004348  0.004743  0.004743  0.004743  0.004743  0.004743  0.004743
# 1  0.004743  0.004743  0.004743  0.004743  0.005138  0.005138  0.005138
# 2  0.004348  0.004348  0.004743  0.004743  0.004743  0.005138  0.004743
# 3  0.004743  0.005138  0.005138  0.005138  0.005138  0.004743  0.004743
# 4  0.004743  0.004743  0.004743  0.005138  0.005138  0.005138  0.004743
#
#           7         8         9    ...         2022      2023      2024  \
# 0  0.004743  0.004743  0.004743    ...     0.005138  0.005138  0.005138
# 1  0.004743  0.004743  0.004743    ...     0.005138  0.005138  0.005138
# 2  0.004743  0.004743  0.004743    ...     0.004743  0.004743  0.004743
# 3  0.004743  0.004743  0.005138    ...     0.004743  0.004743  0.004743
# 4  0.004743  0.004348  0.004348    ...     0.004348  0.004348  0.004348
#
#        2025      2026      2027      2028      2029      2030     Label
# ...

# %% [markdown]
# # Some visualisations with seaborn

# %%
sns.jointplot(x=dataframe[0],y=dataframe[2022],data=dataframe, kind = 'reg')

# %%
sns.jointplot(x=dataframe[0],y=dataframe[2022],data=dataframe, kind = 'hex')

# %%
sns.jointplot(x=dataframe[0],y=dataframe[2022],data=dataframe, kind = 'kde')
# Out:
# C:\Users\Jarvis\Anaconda3\lib\site-packages\matplotlib\contour.py:967: UserWarning: The following kwargs were not used by contour: 'colormap'
#   s)

# %%
#sns.pairplot(dataframe)
sns.pairplot(dataframe,vars=[1000,1001,1002],hue='Label')

# %%
sns.countplot(y=dataframe[1000],label='Label',data=dataframe)

# %%
sns.boxplot(x='Label', y=1011,data=dataframe)

# %%
sns.violinplot(x='Label', y=1011,data=dataframe,split=True)

# %%
sns.stripplot(x='Label', y=1011,data=dataframe,jitter=True)

# %%
#sns.swarmplot(x='Label', y=1011,data=dataframe)

# %%
pivot = dataframe.pivot_table( columns=1,values=0)

# %%
sns.heatmap(pivot,cmap='magma')

# %%
#sns.clustermap(pivot)
