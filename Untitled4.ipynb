# %%
import numpy as np
import pandas as pd
import glue as gl
import sys
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading CSV

# %%
dataframe = pd.read_csv("../../Experimento_Peletron1608/3n163-160817-16o63mev-run01.Wfm.csv", names =['Values'])

# %%
dataframe.head()
# Out:
#      Values
# 0  0.003043
# 1  0.002845
# 2  0.002647
# 3  0.002450
# 4  0.002845

# %%
dataframe_reshape = dataframe.values.reshape(1031,1000)

# %%
dataframe_rs = pd.DataFrame(dataframe_reshape)

# %%
dataframe_rs.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.003043  0.002845  0.002647  0.002450  0.002845  0.003043  0.003043
# 1  0.003043  0.003240  0.003636  0.004228  0.003240  0.003240  0.003438
# 2  0.003240  0.003043  0.003438  0.003240  0.003043  0.003438  0.003636
# 3  0.003438  0.003636  0.003636  0.003833  0.003636  0.003043  0.003438
# 4  0.003043  0.003043  0.002845  0.003043  0.003636  0.003043  0.003240
#
#         7         8         9      ...          990       991       992  \
# 0  0.003438  0.003438  0.003438    ...     0.002845  0.003043  0.004031
# 1  0.003240  0.003636  0.003636    ...     0.003240  0.003240  0.003240
# 2  0.003636  0.003636  0.003438    ...     0.003240  0.003438  0.003240
# 3  0.003833  0.003636  0.003833    ...     0.003240  0.003438  0.003636
# 4  0.003438  0.003240  0.003240    ...     0.004228  0.004228  0.003833
#
#         993       994       995       996       997       998       999
# ...

# %%
dataframe_rs['Label']='oxigenio'

# %%
dataframe_rs.describe()
# Out:
#                0            1            2            3            4    \
# count  1031.000000  1031.000000  1031.000000  1031.000000  1031.000000
# mean      0.003448     0.003465     0.003462     0.003443     0.003438
# std       0.000926     0.000942     0.000929     0.000962     0.000974
# min      -0.000317    -0.001108    -0.001700    -0.002293    -0.001700
# 25%       0.003043     0.003043     0.003043     0.003043     0.003043
# 50%       0.003438     0.003438     0.003438     0.003438     0.003438
# 75%       0.003636     0.003636     0.003636     0.003636     0.003636
# max       0.011738     0.011541     0.011541     0.012134     0.012331
#
#                5            6            7            8            9    \
# count  1031.000000  1031.000000  1031.000000  1031.000000  1031.000000
# mean      0.003439     0.003443     0.003440     0.003468     0.003471
# std       0.001014     0.000999     0.000968     0.000992     0.000987
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(dataframe_rs.iloc[:,dataframe_rs.columns != 'Label'])

# %%
variance_selector = pd.DataFrame(scaler.transform(dataframe_rs.iloc[:,dataframe_rs.columns != 'Label']))

# %%
variance_selector.plot()
