# %%
import numpy as np
import glob
from os import listdir
from os.path import isfile, join
import pandas as pd
import glue as gl
import sys
sys.path.append('/Users/Jarvis/Documents/Mestrado/analise_mestrado')
from dataextractors import extractors as ext
# Out:
# C:\Users\Jarvis\Anaconda3\lib\site-packages\sklearn\lda.py:6: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)

# %%
filenames = glob.glob("../*evento.mat")

# %%
filenames
# Out:
# ['..\\10O16_evento.mat',
#  '..\\1C12_evento.mat',
#  '..\\2C12_evento.mat',
#  '..\\4Cl35a_evento.mat',
#  '..\\5Cl35_evento.mat',
#  '..\\6Cu63_evento.mat',
#  '..\\7Cu63_evento.mat',
#  '..\\8Si23_evento.mat',
#  '..\\9F19_evento.mat']

# %%
total = []
label = []
total_raw =[]    
e = ext()
for idx,filename in enumerate(filenames):
    print(filename)        
    local_raw, local_label = e.getfeatures(filename, False, 'mat',idx)
    total_raw += local_raw
    label += local_label
# Out:
# ..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# filename=..\10O16_evento.mat
# ...

# %%
data_raw = pd.DataFrame(total_raw)
label_raw = pd.DataFrame(label,columns = ['Label'])
tudo_junto = data_raw.join(label_raw)

# %%
tudo_junto.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.004348  0.004743  0.004743  0.004743  0.004743  0.004743  0.004743
# 1  0.004743  0.004743  0.004743  0.004743  0.005138  0.005138  0.005138
# 2  0.004348  0.004348  0.004743  0.004743  0.004743  0.005138  0.004743
# 3  0.004743  0.005138  0.005138  0.005138  0.005138  0.004743  0.004743
# 4  0.004743  0.004743  0.004743  0.005138  0.005138  0.005138  0.004743
#
#           7         8         9    ...         2022      2023      2024  \
# 0  0.004743  0.004743  0.004743    ...     0.005138  0.005138  0.005138
# 1  0.004743  0.004743  0.004743    ...     0.005138  0.005138  0.005138
# 2  0.004743  0.004743  0.004743    ...     0.004743  0.004743  0.004743
# 3  0.004743  0.004743  0.005138    ...     0.004743  0.004743  0.004743
# 4  0.004743  0.004348  0.004348    ...     0.004348  0.004348  0.004348
#
#        2025      2026      2027      2028      2029      2030     Label
# ...

# %% [markdown]
# # Salvando a Bagaça inteira

# %%
Version = '2.0.0'
Path = 'dataframes/data_frame_version_{0}.pkl'.format(Version)
print(Path)
tudo_junto.to_pickle(path=Path)
# Out:
# dataframes/data_frame_version_1.0.0.pkl
